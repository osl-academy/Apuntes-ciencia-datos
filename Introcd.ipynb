# %% [markdown]
# Antes de iniciar, empezar con la descarga de estos paquetes
# https://docs.conda.io/en/latest/miniconda.html#windows-installers
# manual breve de configuración minconda windows
# https://medium.com/@GalarnykMichael/install-python-anaconda-on-windows-2020-f8e188f9a63d

# %% [markdown]
# Aclarar que es python y ver sobre curso

# %% [markdown]
# # Ciencia de datos Intro

# %% [markdown]
# I define a data scientist as someone who finds solutions to problems by analyzing Big or small data using appropriate tools and then tells stories to communicate her findings to the relevant stakeholders. I do not use the data size as a restrictive clause. A data below a certain arbitrary threshold does not make one less of a data scientist. Nor is my definition of a data scientist restricted to particular analytic tools, such as machine learning. As long as one has a curious mind, fluency in analytics, and the ability to communicate the findings, I consider the person a data scientist.

# %% [markdown]
# ![imagen.png](attachment:d8f5428a-3f47-487b-9a83-244a0b0671dc.png)![ciencia de datos workflow](cd1.png)

# %% [markdown]
# Stack mínimo
# >Data Managament:
# >>    SQL, JSON
#
# >Data Integration and Transformation:
# >>    Python, Pandas, numpy, R
# >>    ETL(Extraction, Transformation and Load)
# >>    Extracción de datos de fuentes primarias, transformación(limpieza de datos) y guardado en archivos de formato compatible
#
# >Dat Viz
# >>    matplotlib, numpy, pandas, Panel --- Hue, Kibana, Superset Apache
#
# >Model Building
# >>    Pytorch, Tensorflow, python vanilla
#
# >Model Deployment
# >> Django, Flask, GitHub Actions --- mleap TensorFlowService
#
# >Model Monitoring and Assessment
# >>    Github Actions, ---- Model DB Prometheus
#
# >Code Asset Management
# >>    Git, GitHub, GitLab
#
# >Development Env
# >>    jupyter, VSCode, RStudio-- Apache Zeppelin, Spyder
#
# >Execution Envs
# >>    laptop, Procesamiento en paralelo, Apache Spark --- Flink Ray
#
# >Fully Integrated Visual Tool
# >>    Orange, --- Knime

# %% [markdown]
# ## Ciclo del desarrollo de un projecto de ciencia de datos

# %% [markdown]
# ![ciclo de ciencia de datos](./cycle.png)

# %% [markdown]
# Un artículo interesante [link](https://towardsdatascience.com/machine-learning-models-deployment-123773c476bc)

# %% [markdown]
# ## Empezando con nuestro entorno de trabajo

# %% [markdown]
# ## Configurando GIT

# %% [markdown]
# Instrucciones hechas en carbon [link](https://carbon.now.sh/)

# %% [markdown]
# ![1](1.png)

# %% [markdown]
# ![2d](2.png)

# %% [markdown]
# ![3d](3.png)
